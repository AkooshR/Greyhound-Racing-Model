# %%
import pandas as pd
import numpy as np

marketdata = pd.read_csv('marketdata.csv')
names_set = set(marketdata['selection_md.name'])

#Gets the average back and lay odds
runner_names = []
for name in names_set:
    split = name.split('.',)
    runner_name = split[1]
    runner_names.append(runner_name)
    records = marketdata[marketdata['selection_md.name'] == name]
    back_mean = records['selection_ex.availableToBack.price'].tail(15).mean()
    lay_mean = records['selection_ex.availableToLay.price'].tail(15).mean()
    print(back_mean,lay_mean)
    display(records.tail(15))
distance = input("Please input the race distance: ")
runner_names.append(distance)
avb_details = tuple(runner_names)
# Out:
# 2.083333333333333 2.1783333333333332
#                     publishTime  totalMatched  selection_selectionId  \
# 377  2020-05-04 07:21:18.636000       1114.32               18937450
# 379  2020-05-04 07:21:19.518000       1176.29               18937450
# 380  2020-05-04 07:21:20.185000       1176.29               18937450
# 381  2020-05-04 07:21:21.830000       1176.29               18937450
# 383  2020-05-04 07:21:22.709000       1200.65               18937450
# 384  2020-05-04 07:21:23.588000       1200.65               18937450
# 385  2020-05-04 07:21:26.022000       1200.65               18937450
# 387  2020-05-04 07:21:26.538000       1202.22               18937450
# 389  2020-05-04 07:21:27.210000       1202.42               18937450
# 391  2020-05-04 07:21:28.400000       1217.76               18937450
# 393  2020-05-04 07:21:30.106000       1222.42               18937450
# 394  2020-05-04 07:21:30.624000       1222.42               18937450
# ...

# %%
import main

runner1_name, runner2_name, race_length = avb_details

table1 = main.read_greyhound_data(runner1_name)
table2 = main.read_greyhound_data(runner2_name)

if table1 is None or table2 is None:
    print("ERROR: Unable to retrieve data for one or both greyhounds.")
    exit(1)
else:
    runner1_params = main.fit_normal_dist(table1, race_length)
    runner2_params = main.fit_normal_dist(table2, race_length)

    prob_runner1, prob_runner2 = main.simulate(runner1_params, runner2_params)
    fair_odds1 = 1 / prob_runner1 if prob_runner1 != 0 else None
    fair_odds2 = 1 / prob_runner2 if prob_runner2 != 0 else None

    print(f"\n-----RESULTS-----")

    print(f"{runner1_name}:")
    print(f"\tFair odds    : {fair_odds1:.2f}")
    print(f"\tWin %        : {prob_runner1:.2f}")
    print(f"\tNo. samples  : {len(table1)}")

    print(f"{runner2_name}:")
    print(f"\tFair odds    : {fair_odds2:.2f}")
    print(f"\tWin %        : {prob_runner2:.2f}")
    print(f"\tNo. samples  : {len(table2)}")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[4], line 5
#       1 import main
#       3 runner1_name, runner2_name, race_length = abv_details
# ----> 5 table1 = main.read_greyhound_data(runner1_name)
#       6 table2 = main.read_greyhound_data(runner2_name)
#       8 if table1 is None or table2 is None:
#
# File c:\Users\ratat\OneDrive\Documents\GitHub\Greyhound-Racing-Model\main.py:24, in read_greyhound_data(runner_name)
#      21 url = f'https://www.thegreyhoundrecorder.com.au/greyhounds/{formatted_name}/'
#      23 headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36'}
# ---> 24 tables = pd.read_html(url, storage_options=headers)
#      26 for table in tables:
#      27     if 'Dist' in table.columns and 'Time' in table.columns:
#
# ...
