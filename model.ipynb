# %%
import pandas as pd
import numpy as np

marketdata = pd.read_csv('marketdata.csv')

display(marketdata.head())
# Out:
#                   publishTime  totalMatched  selection_selectionId  \
# 0  2020-05-04 00:06:02.441000           0.0               26859492
# 1  2020-05-04 00:06:02.441000           0.0               18937450
# 2  2020-05-04 00:11:14.572000           0.0               26859492
# 3  2020-05-04 00:11:14.572000           0.0               18937450
# 4  2020-05-04 00:15:56.977000           0.0               26859492
#
#    selection_lastPriceTraded  selection_ex.availableToBack.price  \
# 0                        NaN                                 NaN
# 1                        NaN                                 NaN
# 2                        NaN                                1.98
# 3                        NaN                                1.84
# 4                        NaN                                 NaN
#
#    selection_ex.availableToBack.size  selection_ex.availableToLay.price  \
# 0                                NaN                                NaN
# ...
