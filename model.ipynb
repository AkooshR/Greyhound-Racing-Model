# %%
import pandas as pd
import numpy as np

marketdata = pd.read_csv('springvale-misty_sweet-potato.csv')
names_set = set(marketdata['selection_md.name'])

# Gets the average back and lay odds
race_length = int(input("Please input the race distance: "))
race_date = str(marketdata.tail(1)['publishTime']).split()[1]

runner_names = []

for name in names_set:
    runner_name = name.split('.')[1].strip()
    runner_names.append(runner_name)
    records = marketdata[marketdata['selection_md.name'] == name]
    back_mean = records['selection_ex.availableToBack.price'].tail(15).mean()
    lay_mean = records['selection_ex.availableToLay.price'].tail(15).mean()

    print(f"{runner_name}: BACK ${back_mean:.2f} | LAY ${lay_mean:.2f}")
    display(records.tail(15))
# Out:
# Sweet Potato: BACK $1.63 | LAY $1.84
#                     publishTime  totalMatched        md.eventName  \
# 237  2020-05-04 05:57:53.379000         58.34  Shep (AUS) 4th May
# 239  2020-05-04 05:57:55.283000         80.72  Shep (AUS) 4th May
# 241  2020-05-04 05:57:56.623000         80.72  Shep (AUS) 4th May
# 243  2020-05-04 05:58:00.514000         80.77  Shep (AUS) 4th May
# 245  2020-05-04 05:58:01.913000        120.77  Shep (AUS) 4th May
# 246  2020-05-04 05:58:04.431000        120.77  Shep (AUS) 4th May
# 247  2020-05-04 05:58:06.338000        120.77  Shep (AUS) 4th May
# 248  2020-05-04 05:58:29.550000        120.77  Shep (AUS) 4th May
# 249  2020-05-04 05:58:30.069000        120.77  Shep (AUS) 4th May
# 252  2020-05-04 05:58:50.094000        159.02  Shep (AUS) 4th May
# 254  2020-05-04 05:58:52.235000        159.02  Shep (AUS) 4th May
# 256  2020-05-04 05:58:52.275000        159.02  Shep (AUS) 4th May
# 258  2020-05-04 06:03:26.095000        158.90  Shep (AUS) 4th May
# 260  2020-05-04 06:03:26.696000          0.00  Shep (AUS) 4th May
# 262  2020-05-04 06:03:27.597000          0.00  Shep (AUS) 4th May
#
#                              md.name  marketId  betDelay  bspReconciled  \
# 237  Springvale Misty v Sweet Potato  1.170375         0          False
# 239  Springvale Misty v Sweet Potato  1.170375         0          False
# 241  Springvale Misty v Sweet Potato  1.170375         0          False
# 243  Springvale Misty v Sweet Potato  1.170375         0          False
# 245  Springvale Misty v Sweet Potato  1.170375         0          False
# 246  Springvale Misty v Sweet Potato  1.170375         0          False
# 247  Springvale Misty v Sweet Potato  1.170375         0          False
# 248  Springvale Misty v Sweet Potato  1.170375         0          False
# 249  Springvale Misty v Sweet Potato  1.170375         0          False
# 252  Springvale Misty v Sweet Potato  1.170375         0          False
# 254  Springvale Misty v Sweet Potato  1.170375         0          False
# 256  Springvale Misty v Sweet Potato  1.170375         0          False
# 258  Springvale Misty v Sweet Potato  1.170375         0          False
# 260  Springvale Misty v Sweet Potato  1.170375         0          False
# 262  Springvale Misty v Sweet Potato  1.170375         0          False
#
#      complete     status  runnersVoidable  ...  \
# 237      True       OPEN            False  ...
# 239      True       OPEN            False  ...
# 241      True       OPEN            False  ...
# 243      True       OPEN            False  ...
# 245      True       OPEN            False  ...
# 246      True       OPEN            False  ...
# 247      True       OPEN            False  ...
# 248      True       OPEN            False  ...
# 249      True       OPEN            False  ...
# 252      True       OPEN            False  ...
# 254      True  SUSPENDED            False  ...
# 256      True  SUSPENDED            False  ...
# 258      True  SUSPENDED            False  ...
# 260      True  SUSPENDED            False  ...
# 262      True     CLOSED            False  ...
#
#      selection_ex.availableToLay.size  selection_status  selection_md.name  \
# 237                             10.83            ACTIVE    3. Sweet Potato
# 239                             10.83            ACTIVE    3. Sweet Potato
# 241                             10.83            ACTIVE    3. Sweet Potato
# 243                             10.83            ACTIVE    3. Sweet Potato
# 245                             10.83            ACTIVE    3. Sweet Potato
# 246                             10.83            ACTIVE    3. Sweet Potato
# 247                             10.83            ACTIVE    3. Sweet Potato
# 248                              2.56            ACTIVE    3. Sweet Potato
# 249                              2.56            ACTIVE    3. Sweet Potato
# 252                              4.57            ACTIVE    3. Sweet Potato
# 254                              4.57            ACTIVE    3. Sweet Potato
# 256                               NaN            ACTIVE    3. Sweet Potato
# 258                               NaN            ACTIVE    3. Sweet Potato
# 260                               NaN            ACTIVE    3. Sweet Potato
# 262                               NaN             LOSER    3. Sweet Potato
#
#      selection_handicap  selection_totalMatched  selection_adjustmentFactor  \
# 237                   0                   37.79                         NaN
# 239                   0                   37.86                         NaN
# 241                   0                   37.86                         NaN
# 243                   0                   37.89                         NaN
# 245                   0                   77.89                         NaN
# 246                   0                   77.89                         NaN
# 247                   0                   77.89                         NaN
# 248                   0                   77.89                         NaN
# 249                   0                   77.89                         NaN
# 252                   0                   98.99                         NaN
# 254                   0                   98.99                         NaN
# 256                   0                   98.99                         NaN
# 258                   0                   98.95                         NaN
# 260                   0                    0.00                         NaN
# 262                   0                    0.00                         NaN
#
#      selection_removalDate  selection_sp.actualSP  selection_sp.nearPrice  \
# 237                    NaN                    NaN                     NaN
# 239                    NaN                    NaN                     NaN
# 241                    NaN                    NaN                     NaN
# 243                    NaN                    NaN                     NaN
# 245                    NaN                    NaN                     NaN
# 246                    NaN                    NaN                     NaN
# 247                    NaN                    NaN                     NaN
# 248                    NaN                    NaN                     NaN
# 249                    NaN                    NaN                     NaN
# 252                    NaN                    NaN                     NaN
# 254                    NaN                    NaN                     NaN
# 256                    NaN                    NaN                     NaN
# 258                    NaN                    NaN                     NaN
# 260                    NaN                    NaN                     NaN
# 262                    NaN                    NaN                     NaN
#
#      selection_sp.farPrice
# 237                    NaN
# 239                    NaN
# 241                    NaN
# 243                    NaN
# 245                    NaN
# 246                    NaN
# 247                    NaN
# 248                    NaN
# 249                    NaN
# 252                    NaN
# 254                    NaN
# 256                    NaN
# 258                    NaN
# 260                    NaN
# 262                    NaN
#
# [15 rows x 31 columns]
# Springvale Misty: BACK $2.18 | LAY $8.29
#                     publishTime  totalMatched        md.eventName  \
# 232  2020-05-04 05:57:38.670000         58.34  Shep (AUS) 4th May
# 234  2020-05-04 05:57:40.264000         58.34  Shep (AUS) 4th May
# 235  2020-05-04 05:57:45.407000         58.34  Shep (AUS) 4th May
# 236  2020-05-04 05:57:52.401000         58.34  Shep (AUS) 4th May
# 238  2020-05-04 05:57:55.283000         80.72  Shep (AUS) 4th May
# 240  2020-05-04 05:57:56.008000         80.72  Shep (AUS) 4th May
# 242  2020-05-04 05:58:00.514000         80.77  Shep (AUS) 4th May
# 244  2020-05-04 05:58:01.913000        120.77  Shep (AUS) 4th May
# 250  2020-05-04 05:58:47.198000        120.77  Shep (AUS) 4th May
# 251  2020-05-04 05:58:50.094000        159.02  Shep (AUS) 4th May
# 253  2020-05-04 05:58:52.235000        159.02  Shep (AUS) 4th May
# 255  2020-05-04 05:58:52.275000        159.02  Shep (AUS) 4th May
# 257  2020-05-04 06:03:26.095000        158.90  Shep (AUS) 4th May
# 259  2020-05-04 06:03:26.696000          0.00  Shep (AUS) 4th May
# 261  2020-05-04 06:03:27.597000          0.00  Shep (AUS) 4th May
#
#                              md.name  marketId  betDelay  bspReconciled  \
# 232  Springvale Misty v Sweet Potato  1.170375         0          False
# 234  Springvale Misty v Sweet Potato  1.170375         0          False
# 235  Springvale Misty v Sweet Potato  1.170375         0          False
# 236  Springvale Misty v Sweet Potato  1.170375         0          False
# 238  Springvale Misty v Sweet Potato  1.170375         0          False
# 240  Springvale Misty v Sweet Potato  1.170375         0          False
# 242  Springvale Misty v Sweet Potato  1.170375         0          False
# 244  Springvale Misty v Sweet Potato  1.170375         0          False
# 250  Springvale Misty v Sweet Potato  1.170375         0          False
# 251  Springvale Misty v Sweet Potato  1.170375         0          False
# 253  Springvale Misty v Sweet Potato  1.170375         0          False
# 255  Springvale Misty v Sweet Potato  1.170375         0          False
# 257  Springvale Misty v Sweet Potato  1.170375         0          False
# 259  Springvale Misty v Sweet Potato  1.170375         0          False
# 261  Springvale Misty v Sweet Potato  1.170375         0          False
#
#      complete     status  runnersVoidable  ...  \
# 232      True       OPEN            False  ...
# 234      True       OPEN            False  ...
# 235      True       OPEN            False  ...
# 236      True       OPEN            False  ...
# 238      True       OPEN            False  ...
# 240      True       OPEN            False  ...
# 242      True       OPEN            False  ...
# 244      True       OPEN            False  ...
# 250      True       OPEN            False  ...
# 251      True       OPEN            False  ...
# 253      True  SUSPENDED            False  ...
# 255      True  SUSPENDED            False  ...
# 257      True  SUSPENDED            False  ...
# 259      True  SUSPENDED            False  ...
# 261      True     CLOSED            False  ...
#
#      selection_ex.availableToLay.size  selection_status    selection_md.name  \
# 232                              6.77            ACTIVE  1. Springvale Misty
# 234                              6.77            ACTIVE  1. Springvale Misty
# 235                              6.77            ACTIVE  1. Springvale Misty
# 236                             61.00            ACTIVE  1. Springvale Misty
# 238                             61.00            ACTIVE  1. Springvale Misty
# 240                              0.01            ACTIVE  1. Springvale Misty
# 242                             61.00            ACTIVE  1. Springvale Misty
# 244                             61.00            ACTIVE  1. Springvale Misty
# 250                             16.95            ACTIVE  1. Springvale Misty
# 251                             61.00            ACTIVE  1. Springvale Misty
# 253                             61.00            ACTIVE  1. Springvale Misty
# 255                               NaN            ACTIVE  1. Springvale Misty
# 257                               NaN            ACTIVE  1. Springvale Misty
# 259                               NaN            ACTIVE  1. Springvale Misty
# 261                               NaN            WINNER  1. Springvale Misty
#
#      selection_handicap  selection_totalMatched  selection_adjustmentFactor  \
# 232                   0                   20.55                         NaN
# 234                   0                   20.55                         NaN
# 235                   0                   20.55                         NaN
# 236                   0                   20.55                         NaN
# 238                   0                   42.86                         NaN
# 240                   0                   42.86                         NaN
# 242                   0                   42.88                         NaN
# 244                   0                   42.88                         NaN
# 250                   0                   42.88                         NaN
# 251                   0                   60.03                         NaN
# 253                   0                   60.03                         NaN
# 255                   0                   60.03                         NaN
# 257                   0                   59.95                         NaN
# 259                   0                    0.00                         NaN
# 261                   0                    0.00                         NaN
#
#      selection_removalDate  selection_sp.actualSP  selection_sp.nearPrice  \
# 232                    NaN                    NaN                     NaN
# 234                    NaN                    NaN                     NaN
# 235                    NaN                    NaN                     NaN
# 236                    NaN                    NaN                     NaN
# 238                    NaN                    NaN                     NaN
# 240                    NaN                    NaN                     NaN
# 242                    NaN                    NaN                     NaN
# 244                    NaN                    NaN                     NaN
# 250                    NaN                    NaN                     NaN
# 251                    NaN                    NaN                     NaN
# 253                    NaN                    NaN                     NaN
# 255                    NaN                    NaN                     NaN
# 257                    NaN                    NaN                     NaN
# 259                    NaN                    NaN                     NaN
# 261                    NaN                    NaN                     NaN
#
#      selection_sp.farPrice
# 232                    NaN
# 234                    NaN
# 235                    NaN
# 236                    NaN
# 238                    NaN
# 240                    NaN
# 242                    NaN
# 244                    NaN
# 250                    NaN
# 251                    NaN
# 253                    NaN
# 255                    NaN
# 257                    NaN
# 259                    NaN
# 261                    NaN
#
# [15 rows x 31 columns]

# %%
import main

runner1_name, runner2_name = runner_names[0], runner_names[1]

table1 = main.read_greyhound_data(runner1_name, race_length, race_date)
table2 = main.read_greyhound_data(runner2_name, race_length, race_date)

if table1.shape[0] == 0 or table2.shape[0] == 0:
    print("ERROR: Unable to retrieve data for one or both greyhounds.")
    exit(1)
else:
    runner1_params = main.fit_normal_dist(table1)
    runner2_params = main.fit_normal_dist(table2)

    prob_runner1, prob_runner2 = main.simulate(runner1_params, runner2_params)
    fair_odds1 = 1 / prob_runner1 if prob_runner1 != 0 else None
    fair_odds2 = 1 / prob_runner2 if prob_runner2 != 0 else None

    print(f"\n-----RESULTS-----")

    print(f"{runner1_name}:")
    print(f"\tFair odds    : {fair_odds1:.2f}")
    print(f"\tWin %        : {100*prob_runner1:.2f}")
    print(f"\tNo. samples  : {len(table1)}")

    print(f"{runner2_name}:")
    print(f"\tFair odds    : {fair_odds2:.2f}")
    print(f"\tWin %        : {100*prob_runner2:.2f}")
    print(f"\tNo. samples  : {len(table2)}")

# update
# Out:
# WARNING: less than 5 found!
# ERROR: Unable to retrieve data for one or both greyhounds.
